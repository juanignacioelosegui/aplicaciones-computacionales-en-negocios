# %% [markdown]
# # Clase 4: Procesos estocásticos

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Ejercicio 2 (Guia 3): Modelo para el precio de YPF

# %% [markdown]
# Queremos implementar un random walk geométrico como modelo para la evolución diaria de la acción de YPF (en dólares) e implementarlo como simulación de Monte Carlo.
#
# $$ S_{i+1} = S_i \cdot (1 + \mu \Delta + \sigma Z_{i+1} \sqrt{\Delta}) $$

# %% [markdown]
# Necesitamos conocer:
# - El precio inicial de la acción ($S_0$ = ?)
# - Delta de tiempo ($\Delta$ = ?)

# %%
# COMPLETAR
delta = 
S_0 =

# %% [markdown]
# Implementar una funcion que simule $m$ caminos de $S_i$ para $T$ periodos de tiempo.

# %%
def S(S_0, mu, sigma, delta, T, m):   
    # COMPLETAR
    pass

# %% [markdown]
# Queremos estimar ahora los valores de $\mu$ y $\sigma$ en base a los datos históricos de la acción de YPF.
#
# Para ello, pensemos que significa $\mu$ y $\sigma$ en el modelo de random walk geométrico y como podemos estimarlos a partir de los datos históricos.

# %%
# COMPLETAR

# %% [markdown]
# Con el modelo ya calibrado, queremos estimar:
# - La media de la acción de YPF en 1 mes
# - La varianza de la acción de YPF en 1 mes
# - La probabilidad de la perdida en el valor de la acción de YPF en 1 mes
#
# Estima estos valores simulando $m = 100, 10000, 100000$ caminos.

# %%
# COMPLETAR

# %% [markdown]
# ### Ejercicio 3

# %% [markdown]
# Considerá un modelo con reversión a la media del tipo
#
# $$ S_{i+1} = S_i + \kappa (\theta - S_i) \Delta + \sigma \sqrt{\Delta} Z_{i+1}) $$

# %% [markdown]
# donde Z es 1 o -1 en cada paso.
# Tomá $\Delta$ = 1/365, $S_0$ = 0, $\theta$ = 0, $\sigma$ = 0.2.
#
# Implementá una simulación de este modelo y estimá (sobre un número suficientemente grande de caminos)
#
# cuál es el número medio de veces que un camino
# del proceso atraviesa el nivel $S = \theta$ en un horizonte de 5 años si, $\kappa = 0$, $\kappa = 10$ o $\kappa = 100$.

# %%
import numpy as np

Delta =
S0 = 
theta = 
sigma = 

n_years = 5
n_steps = int(n_years / Delta)
n_paths = 100

for kappa in [0, 10, 100]:

    cruces = []

    for _ in range(n_paths):

        S = 
        count = 

        for _ in range(n_steps):

            Z = 

            S_new = 

            #Hubo un cruce de theta?
            if :
                count += 1

            S = S_new

        cruces.append(count)

    print(kappa, np.mean(cruces))
